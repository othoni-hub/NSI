# %% [markdown]
# <a href="https://colab.research.google.com/github/othoni-hub/NSI/blob/main/M1_NSI_Pandas_et_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Master MEEF M1 - NSI**
# # **TRAITEMENT ET VISUALISATION DE DONNÉES EN TABLES AVEC PANDAS ET MATPLOTLIB**
#
# *********************
# ## Olivier THÖNI
#
# ### FACULTÉ d'ÉDUCATION UCO
# *********************
# *document sous licence Creative Commons - CC : By/NC/SA*
#
# *********************

# %% [markdown]
# ![](https://drive.google.com/uc?id=1gqKhSgmH1czG68HSLe-fLONw-VvmgCWL)
#
# *********************
# *document sous licence Creative Commons - CC : By/NC/SA*
#
# *********************

# %% [markdown]
# ![](https://drive.google.com/uc?id=125xpPw6WTqGiGiNyEB3T_ncqGNNNqy7A)

# %% [markdown]
# ***Excellents tutos Python ici © :***
#
# * http://www.python-simple.com/ :
#     * http://www.python-simple.com/python-pandas/panda-intro.php
#     * http://www.python-simple.com/python-matplotlib/matplotlib-intro.php

# %% [markdown]
# **Pandas par les exemples**
#
# ***Pandas*** permet de fabriquer des variables d'un type qui lui est propre : les ***DataFrames***.
#
# À partir de données construites sur place ou, de fichiers au format .csv ou au format .json, enregistrés sur le disque dur ou téléchargés depuis l'internet, on peut traiter ces données et les analyser.
#
# Les DataFrames sont des tableaux, indexés ou non, étiquetés ou non, de données de types multiples, éventuellement très massifs.
#
# Une colonne d'un DataFrame s'appelle une ***Série***, la plupart de ces séries portent un nom en 1<sup>ère</sup> ligne (ligne n°0) du DataFrame. La "Série" est d'ailleurs en soi un type construit de données de Pandas : unidimensionnel et homogène.
#
# Chaque ligne d'un DataFrame est repérée par un ***Index***, correspondant à chaque instance ("individu") de la base de données. Ces deux termes, ***Série*** et ***Index*** sont très importants !
#
# Pandas dispose de fonctions et de méthodes pour en faire des sous-tableaux, les trier horizontalement ou verticalement, les fusionner de diverses façons, opérer sur les données, etc, et surtout, en effectuer des traitements statistiques. Il dispose aussi de quelques fonctionnalités graphiques de base, mais qui parfois peuvent suffire.
#
# Nous allons en explorer quelques unes des principales.
#
# Quant à ***Matplotlib***, il s'agit d'une bibliothèque permettant de réaliser de très nombreuses espèces de graphiques autour de ces données, car, à l'instar du *Data Scientist*, en matière d'analyse de données, la première chose à effectuer est ce que l'on nomme le pré-traitement : nettoyage et visualisation des données en 1,2, ou 3 dimensions. Au-delà, on réduit éventuellement le nombre de dimensions (de variables présentes) et la taille de ces données, avec des outils tels les classifieurs ou l'Analyse en Composantes Principales (ACP), afin de pouvoir s'en faire la meilleure idée possible.

# %% [markdown]
# ## **1. Plusieurs façons de transformer des données en DataFrame Pandas**

# %% [markdown]
# ### **a/ Données fabriquées sur place**
#
# source : http://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot

# %%
import pandas as pd

df_fictif = pd.DataFrame({
    'name':['john','mary','peter','jeff','jane','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    'num_children':[2,0,0,3,2,1,4],
    'num_pets':[5,1,0,5,2,2,3]
})

# %% [markdown]
# Ici, après avoir importé *Pandas* sous l'alias *'pd'*, la variable *df_fictif* est un DataFrame créé de toute pièce à partir d'un dictionnaire (rappel : encadré par des {...}, avec des clés ('name', 'age', etc.) et des valeurs (les listes ['John',...],[23,...], [...,'F',...], etc.) . Elle est transformée en DataFrame par la fonction pd.DataFrame(...).
#
# Comme on peut le voir, les données sont hétérogènes : certaines variables (séries) sont alphanumériques, d'autres numériques.
#
# Affichons le résultat :

# %%
df_fictif
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0
# 3   jeff   19      M          dc             3         5
# 4   jane   45      M  california             2         2
# 5   lisa   33      F       texas             1         2
# 6   jose   20      M       texas             4         3

# %% [markdown]
# Pour les tableaux longs, on peut n'afficher que la tête ou la queue :(observez au passage l'indexation automatique)

# %%
df_fictif.head(3)
# Out:
#     name  age gender       state  num_children  num_pets
# 0   john   23      M  california             2         5
# 1   mary   78      F          dc             0         1
# 2  peter   22      M  california             0         0

# %%
df_fictif.tail(2)
# Out:
#    name  age gender  state  num_children  num_pets
# 5  lisa   33      F  texas             1         2
# 6  jose   20      M  texas             4         3

# %%
df_fictif.plot.pie(y='num_pets')
# Out:
# <Axes: ylabel='num_pets'>

# %%
df_fictif.plot.pie(y='state')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-1180761abb29> in <cell line: 1>()
# ----> 1 df_fictif.plot.pie(y='state')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in pie(self, **kwargs)
#    1610         ):
#    1611             raise ValueError("pie requires either y column or 'subplots=True'")
# -> 1612         return self(kind="pie", **kwargs)
#    1613
#    1614     def scatter(self, x, y, s=None, c=None, **kwargs) -> PlotAccessor:
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
# ...

# %% [markdown]
# ### **b/ Import des données au format .csv depuis internet ou son ordinateur**
#
# Les fichiers au format .csv (*Comma Separated Value*) permettent la sérialisation de données en tables (c'est-à-dire leur traduction en format texte avec séparateurs de lignes et de colonnes) afin de les transporter via internet.
#
# Pandas nous facilite la vie, puisqu'il suffit d'utiliser la fonction *pd.read_csv(...)* pour les désérialiser directement en DataFrame Pandas.
#
# La commande est la même si le fichier .csv est sur le disque dur, il suffit de saisir très précisément le chemin d'accès au fichier .csv
#
# De nombreux sites proposent l'accès à des données ouvertes.

# %%
url = 'https://cinema-public.opendatasoft.com/explore/dataset/meilleures-audiences-en-salles-depuis-1945public/download/'
df_boxoffice = pd.read_csv(url, sep = ';')
df_boxoffice.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-a233fdbbf1b5> in <cell line: 2>()
#       1 url = 'https://cinema-public.opendatasoft.com/explore/dataset/meilleures-audiences-en-salles-depuis-1945public/download/'
# ----> 2 df_boxoffice = pd.read_csv(url, sep = ';')
#       3 df_boxoffice.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %% [markdown]
# **Autre exemple :**
#
# source : https://www.actuia.com/tutoriel/tutoriel-dinitiation-a-lia-python-pandas-et-matplotlib-partie-2/

# %%
url = 'https://raw.githubusercontent.com/Shmilowitz/PythonIMDbExercise/master/movies.csv.csv'
df_films = pd.read_csv(url, sep = ',')
df_films.head()
# Out:
#    Unnamed: 0                     title  year  length  budget  rating  votes  \
# 0           1                         $  1971     121     NaN     6.4    348
# 1           2         $1000 a Touchdown  1939      71     NaN     6.0     20
# 2           3    $21 a Day Once a Month  1941       7     NaN     8.2      5
# 3           4                   $40,000  1996      70     NaN     8.2      6
# 4           5  $50,000 Climax Show, The  1975      71     NaN     3.4     17
#
#      r1    r2   r3  ...    r9   r10  mpaa  Action  Animation  Comedy  Drama  \
# 0   4.5   4.5  4.5  ...   4.5   4.5   NaN       0          0       1      1
# 1   0.0  14.5  4.5  ...   4.5  14.5   NaN       0          0       1      0
# 2   0.0   0.0  0.0  ...  24.5  24.5   NaN       0          1       0      0
# 3  14.5   0.0  0.0  ...  34.5  45.5   NaN       0          0       1      0
# 4  24.5   4.5  0.0  ...   0.0  24.5   NaN       0          0       0      0
#
#   Documentary  Romance  Short
# ...

# %% [markdown]
# Comme nous pouvons le voir, le fichier csv contient les colonnes suivantes :
#
# **Unnamed** :Colonne sans nom (correspondant à un numéro identifiant le film, nous ne l’utiliserons pas).
#
# **title** : il s’agit du titre du film
#
# **year** : année de réalisation du film
#
# **length** : durée du film, en minutes
#
# **budget** : budget du film (NaN si non connu)
#
# **rating** : note du film
#
# **votes** : nombre de votes
#
# **r1 à r10** : % de note reçues respectivement égales de 1/10 à 10/10
#
# **mpaa** : classification du film (tous publics, PG-13 ..)
#
# **Genres** : une colonne par genre, contenant la valeur 0 si ce film n’est pas classé dans le genre correspondant, 1 s’il est classé dans le genre. Un film peut être classé dans différents genres.
#
# ***Remarques importantes*** :
#
# * La variable catégorielle "Genre" est difficilement utilisable autrement que pour tracer un "camembert". Pour pouvoir établir une "distance" entre deux films, on a donc séparés ses 6 catégories ('Action', 'Animation', 'Comédie', 'Drame', 'Documentaire', 'romance', 'Court-métrage') en 6 variables statistiques dites de Bernoulli, valant 0 ou 1.
#
# * Certaines valeurs contiennent 'NaN' (*Not A Number*), qui vont être pénibles dans les futurs traitements, il va falloir leur régler leur compte...

# %% [markdown]
# ### **c/ Import de données sérialisées au format .json**
#
# Le format .json (*JavaScript Object Notation*) est un format voisin du .csv, aux séparateurs près.
#
# La commande Pandas pour désérialiser des données du format .json vers un DataFrame est la suivante : *pd.read_json(...)*
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **2. Accéder aux données**
#
# sources :
# * https://ourcodingclub.github.io/2018/04/18/pandas-python-intro.html
# * https://www.actuia.com/tutoriel/tutoriel-dinitiation-a-lia-python-pandas-et-matplotlib-partie-2/

# %% [markdown]
# ### **a/ accès à une colonne (= variable)**
#
# Par exemple, sur notre DataFrame concernant les records au box-office

# %%
df_boxoffice['title'].head(10)
# Out:
# 0                           $
# 1           $1000 a Touchdown
# 2      $21 a Day Once a Month
# 3                     $40,000
# 4    $50,000 Climax Show, The
# 5                       $pent
# 6                     $windle
# 7                        '15'
# 8                         '38
# 9                     '49-'17
# Name: title, dtype: object

# %%
df_boxoffice.titre
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-bf67aa0816fc> in <cell line: 1>()
# ----> 1 df_boxoffice.titre
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'titre'

# %% [markdown]
# **Ne conserver que certaines colonnes :**

# %%
df_boxoffice[['title','year']]
# Out:
#                           title  year
# 0                             $  1971
# 1             $1000 a Touchdown  1939
# 2        $21 a Day Once a Month  1941
# 3                       $40,000  1996
# 4      $50,000 Climax Show, The  1975
# ...                         ...   ...
# 58783                 tom thumb  1958
# 58784               www.XXX.com  2003
# 58785    www.hellssoapopera.com  1999
# 58786                       xXx  2002
# 58787   xXx: State of the Union  2005
#
# [58788 rows x 2 columns]

# %% [markdown]
# ### **c/ Filtrer**

# %%
df_boxoffice.annee_de_sortie < 1950

# %%
df_boxoffice[df_boxoffice.annee_de_sortie < 1948].count()

# %% [markdown]
# ### **b/ Accès à une ligne (= index)**

# %%
df_boxoffice.iloc[195]

# %%
df_boxoffice.iloc[195][0]

# %%
df_boxoffice['titre'][195]

# %% [markdown]
# ### **d/ Extraction d'une plage d'index**

# %%
df_boxoffice[1:6]

# %% [markdown]
# et si l'on veut ne garder que certaines colonnes :

# %%
df_boxoffice.loc[3:6,["annee_de_sortie","titre"]]

# %% [markdown]
# ### **e/ Indexation sur les colonnes**
#
# On peut faire l'indexation du DataFrame sur une colonne :

# %%
df_boxoffice.set_index('titre')

# %% [markdown]
# Il est possible également d'indexer sur plusieurs colonnes :

# %%
df_boxoffice.reset_index(drop=True, inplace=True)

# %%
df_boxoffice.set_index(['annee_de_sortie','realisateur']).sort_index()

# %% [markdown]
# ### **e/ Calculer sur des données groupées : la méthode *groupby des DataFrames Pandas***
#
# Par exemple, dans le jeu de données *df_films*, si l'on veut compter les films par année de sortie, cela donnera cela :

# %%
df_films.groupby("year")["title"].count()
# Out:
# year
# 1893       1
# 1894       9
# 1895       3
# 1896      13
# 1897       9
#         ...
# 2001    2121
# 2002    2168
# 2003    2158
# 2004    1945
# 2005     349
# Name: title, Length: 113, dtype: int64

# %% [markdown]
# ...Et si l'on veut calculer la moyenne des durées des films ainsi groupés par année de sortie :

# %%
df_films.groupby(["year"])["length"].mean()
# Out:
# year
# 1893     1.000000
# 1894     1.000000
# 1895     1.000000
# 1896     1.307692
# 1897     1.000000
#           ...
# 2001    79.174446
# 2002    77.118081
# 2003    75.848934
# 2004    78.826735
# 2005    86.151862
# Name: length, Length: 113, dtype: float64

# %% [markdown]
# Ce sera encore plus édifiant graphiquement !

# %%
import matplotlib.pyplot as plt
df_films.groupby(["year"])["length"].mean().plot()
plt.show()

# %% [markdown]
# En visualisant cette courbe, il est beaucoup plus facile de constater l’évolution de la durée moyenne des films au fil des années n’est-ce pas ? Nous pouvons voir que si la durée des films n’évolue pas de façon linéaire, elle a globalement augmenté au fil des années, bien qu’elle ait notablement diminué entre la fin des années 90 et le début des années 2000.
#
# Il est possible de tracer plusieurs courbes dans un même graphique, nous pouvons par exemple comparer la note moyenne des films d’action et comiques selon les années :

# %%
df_films[df_films["Action"]==1].groupby(["year"])["rating"].mean().plot(legend=True,label="Action")
df_films[df_films["Comedy"]==1].groupby(["year"])["rating"].mean().plot(legend=True,label="Comédie")
plt.show()

# %% [markdown]
# ... Mais nous reviendrons un peu plus tard sur l'importance de ces visualisations des données !
#
#
#
# ---
# **Commandes composées**

# %%
df_films[["year","rating"]].mean()
# Out:
# year      1976.133582
# rating       5.932850
# dtype: float64

# %% [markdown]
# Le chaînage peut être plus complexe, dans l’exemple suivant nous affichons les titres et notes des 3 meilleurs films de l’année 1981 (la méthode de DataFrames *sort_values* sera détaillée dans le paragraphe suivant) :

# %%
df_films[df_films["year"]==1981].sort_values(by="rating",ascending=False)[["title","rating"]].head(3)

# %% [markdown]
# C'est presque des requêtes SQL... C'est ce qu'on nomme le NoSQL (Not Only SQL)
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **3. Plusieurs façons de trier un DataFrame**
#
# source : https://kanoki.org/2020/01/28/sort-pandas-dataframe-and-series/
#
# traduit de l'anglais grâce à  : https://www.deepl.com/fr/translator
#
# Créons une base de données de 11 pays avec leurs émissions de CO2 et leur population, ainsi qu'une colonne pour le continent auquel ils appartiennent :

# %%
import numpy as np # juste pour quelques laisser quelques données vides...
import pandas as pd

df_CO2 = pd.DataFrame({
    'Country':['USA','China','India','Russia','Switzerland','Japan','Sweden','Singapore','South Korea','UK','Australia'],
    'Co2_emission':[5107.393,10877.218,2454.774,1764.866,39.738,1320.776,np.NaN,55.018,673.324,379.150,764.866],
    'Population_million':[329,1433,1366,145,8.5,126,10,5.8,51,67,np.NaN],
    'Continent': ['NA','Asia','Asia','EU','EU','Asia','EU','Asia','Asia','EU','AU']
                 })

df_CO2

# %% [markdown]
# ### **a/ Trier par valeur (= sur une variable)**
#
# Ici, nous trions la base de données par valeur de colonne, en l'occurrence  *population_million*
#
# La fonction *sort_values* trie le DataFrame en fonction des valeurs de colonne fournies en premier argument et en paramétrant l'ordre croissant Vrai/Faux, les résultats s'affichent dans cet ordre

# %%
df_CO2.sort_values('Population_million',ascending = False)

# %% [markdown]
# **variante : trier le DataFrame avec les Nan à la fin**
#
# La colonne contient la valeur NaN, on peut choisir d'afficher les valeurs NaN soit sur la ligne supérieure ou inférieure du DataFrame trié, en ajoutant l'attribut *na_position*

# %%
df_CO2.sort_values('Population_million',ascending = False,na_position = 'last')

# %% [markdown]
# ### **b/ Tri des lignes du DataFrame sur critères multi-colonne**
#
# Vous pouvez également fournir la liste des colonnes à trier et leur ordre ainsi qu'une liste de booléens.
#
# Ici, nous trions les données d'abord par colonne CO2_emission et ensuite par Population_million et nous voulons l'ordre des émissions de CO2 en ordre croissant et de la population_million en ordre décroissant.

# %%
df_CO2.sort_values(by = ['Co2_emission','Population_million'],ascending = [True,False])

# %% [markdown]
# Il est alors possible de réindexer la liste selon son nouvel ordre :

# %%
df_CO2.sort_values(by = ['Co2_emission','Population_million'],ascending = [True,False]).reset_index(drop=True)

# %% [markdown]
# ### **c/ Trier une colonne de texte par ordre alphabétique**
#
# avec la méthode *sort_values*

# %%
df_CO2.sort_values(by='Country')

# %% [markdown]
# ### **d/ Trier par index**
#
# Comme vu plus haut, une fois un DataFrame indexé, on peut le trier sur cet index avec la méthode *sort_index()*
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## **4.Plusieurs façons de fusionner des données de DataFrames**
#
# source : https://towardsdatascience.com/combining-dataframes-using-pandas-b9e2e83b9869

# %% [markdown]
# Fabriquons de toute pièce deux petits DataFrames :

# %%
df1 = pd.DataFrame({'column_a' : [1,2,3,4],
                    'column_b' : ['a','b','c','d'],
                    'column_c' : [True, True, False, True]})

df2 = pd.DataFrame({'column_a' : [1,2,9,10],
                    'column_b' : ['a','k','l','m'],
                    'column_c' : [False, False, False, True]})
df1

# %%
df2

# %% [markdown]
# ### **a/ Concaténation**
#
# Une première façon de combiner deux DataFrames est la fonction ***concat()***.
# Sans autre précision, elle met simplement bout à bout les deux tableaux, verticalement, en ajoutant des lignes, quitte à obtenir des doublons sur les index.

# %%
df = pd.concat([df1, df2])
df

# %% [markdown]
# Pour réindexer les lignes, on rajoute l'attribut *ignore_index = True* :

# %%
df = pd.concat([df1, df2], ignore_index = True)
df

# %% [markdown]
# En précisant *axis = 1*, on va accoler les deux tableaux en largeur, en ajoutant des colonnes, quitte à créer des doublons dans les entêtes de colonnes.
# Si deux lignes portent le même index, elles sont fusionnées, quitte à compléter les cases vides par des *NaN*

# %%
df = pd.concat([df1, df2], axis = 1)
df

# %% [markdown]
# ### **b/ Jointure**
#
# Ce qui distingue la jointure de la concaténation est l'élimination des doublons.
# Si l'option ***inner*** est choisie, seules les lignes avec des indices communs seront jointes, quitte à obtenir des doublons dans les noms de colonnes.

# %% [markdown]
# Réindexons le 2<sup>ème</sup> DataFrame pour que l'illustration soit plus parlante...

# %%
df2 = pd.DataFrame({'column_a' : [1,2,9,10],
                    'column_b' : ['a','k','l','m'],
                    'column_c' : [False, False, False, True]}, index = [2,3,4,5])

df2

# %%
df = pd.concat([df1, df2], axis = 1, join = 'inner')
df

# %% [markdown]
# Si le paramètre *join* est placé à ***outer*** (sa valeur par défaut), tous les index figurent dans le DataFrame final, quitte à remplir les case vides par des *NaN*

# %%
df = pd.concat([df1, df2], axis = 1, join = 'outer')
df

# %% [markdown]
# Pandas permet également de rajouter des étiquettes pour indiquer de quel DataFrame proviennent chaque part :

# %%
df = pd.concat([df1, df2], keys = ['df1','df2'])
df

# %% [markdown]
# Ceci permet d'accéder plus facilement aux diverse parties du DataFrame final :

# %%
df.loc['df2']

# %% [markdown]
# **À retenir :** La fonction ***concat()*** fabrique une copie des données !

# %% [markdown]
# ### **c/ Fusion**
#
# Là où la concaténation se contentait de mettre bout à bout les données, la fusion (***merge()***) va combiner de manière plus flexible les DataFrames en se basant sur les valeurs dans les colonnes partagées.
# Le paramètre **on** indique sur quelle(s) colonne(s) va se situer la fusion.

# %%
df = pd.merge(df1, df2, on = "column_a")
df

# %% [markdown]
# Ici, par défaut, seules les lignes communes, dans les valeurs de la colonne sur laquelle s'opère la fusion, sont conservées.
# Cela se règle par un paramètre ***how***, réglé par défaut sur ***inner***.
# Pour conserver toutes les lignes, on règle ce paramètre à ***outer***.
# Les cases vides sont alors fixées à NaN.

# %%
df = pd.merge(df1, df2, on = "column_a", how = 'outer')
df

# %% [markdown]
# ### **d/ Pivot (tableau croisé dynamique)**
#
# Cette méthode consiste à créer une seconde table en utilisant les valeurs d’une colonne comme nom de colonnes.
#
# ![](https://drive.google.com/uc?id=15PyZ3qP3VAD-w0o8XpqJK_lqnCTYPtIh)

# %%
df_TableCroisee = df.pivot('column_a','column_b_x', 'column_b_y')
df_TableCroisee

# %% [markdown]
# ## **5. Un exemple complet d'analyse statistique et graphique doublé d'un petit cours d'oenologie**
#
# source : https://github.com/dipanjanS/practical-machine-learning-with-python/blob/master/bonus%20content/effective%20data%20visualization/Bonus%20-%20Effective%20Multi-dimensional%20Data%20Visualization.ipynb
#
# traduit de l'anglais grâce à DeepL : https://www.deepl.com/fr/translator
#
#
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### **a/ Chargement et fusion des données**
#
# Les données sont issues de deux *datasets*, concernant les vins rouges et les vins blancs, que nous allons fusionner

# %%
white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=';')
red_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')

# store wine type as an attribute
red_wine['wine_type'] = 'red'
white_wine['wine_type'] = 'white'

# bucket wine quality scores into qualitative quality labels
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
                                                          if value <= 5 else 'medium'
                                                              if value <= 7 else 'high')
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
                                           categories=['low', 'medium', 'high'])
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
                                                              if value <= 5 else 'medium'
                                                                  if value <= 7 else 'high')
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
                                             categories=['low', 'medium', 'high'])

# merge red and white wine datasets
wines = pd.concat([red_wine, white_wine])

# re-shuffle records just to randomize data points
wines = wines.sample(frac=1, random_state=42).reset_index(drop=True)

wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.17         0.74            12.8      0.045
# 1            7.7              0.64         0.21             2.2      0.077
# 2            6.8              0.39         0.34             7.4      0.020
# 3            6.3              0.28         0.47            11.2      0.040
# 4            7.4              0.35         0.20            13.9      0.054
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 24.0                 126.0  0.99420  3.26       0.38
# 1                 32.0                 133.0  0.99560  3.27       0.45
# 2                 38.0                 133.0  0.99212  3.18       0.44
# 3                 61.0                 183.0  0.99592  3.12       0.51
# 4                 63.0                 229.0  0.99888  3.11       0.50
#
#    alcohol  quality wine_type quality_label
# ...

# %%
print('Le jeu de données comporte ',len(wines),' vins.')

# %% [markdown]
# **Comprendre le vin**
#
# Le vin est une boisson alcoolisée fabriquée à partir de raisins qui est fermentée sans ajout de sucres, d'acides, d'enzymes, d'eau ou d'autres nutriments.
#
# Le vin rouge est fabriqué à partir de raisins rouges et noirs foncés. La couleur varie généralement de diverses nuances de rouge, de brun et de violet. Il est produit à partir de raisins entiers, y compris la peau, ce qui ajoute à la couleur et à la saveur des vins rouges et leur donne un goût riche.
#
# Le vin blanc est produit à partir de raisins blancs sans peau ni pépins. La couleur est généralement jaune paille, jaune vert ou jaune or. La plupart des vins blancs ont une saveur légère et fruitée par rapport aux vins rouges plus riches.
#
# **Comprendre les attributs et les propriétés du vin**
# * une acidité fixe (***fixed acidity***) en g/dm<sup>3</sup> : Les acides sont l'une des propriétés fondamentales du vin et contribuent grandement à son goût. Une réduction significative des acides peut conduire à un goût plat du vin. Les acides fixes comprennent les acides tartrique, malique, citrique et succinique que l'on trouve dans le raisin (sauf le succinique).
#
#
# * l'acidité volatile (***volatile acidity***) en g/dm<sup>3</sup> : Ces acides doivent être distillés du vin avant de terminer le processus de production. Ils sont principalement constitués d'acide acétique, bien que d'autres acides comme les acides lactique, formique et butyrique puissent également être présents. L'excès d'acides volatils est indésirable et entraîne une saveur désagréable.
#
# * l'acide citrique (***citric acid***) en g/dm<sup>3</sup> : C'est l'un des acides fixes qui donnent au vin sa fraîcheur. Il est généralement consommé en grande partie pendant le processus de fermentation et parfois ajouté séparément pour donner plus de fraîcheur au vin.
#
# * sucre résiduel (***residual sugar***) en g/dm<sup>3</sup> : Il s'agit généralement du sucre naturel du raisin qui reste après l'arrêt du processus de fermentation. Il est généralement exprimé en $\frac{g}{dm^3}$ dans l'ensemble de données.
#
# * chlorures (***chlorides***) en g/dm<sup>3</sup> : C'est généralement un élément majeur de la salinité du vin.
#
# * dioxyde de soufre libre (***free sulfur dioxide***) en mg/dm<sup>3</sup> : C'est la partie du dioxyde de soufre qui, lorsqu'elle est ajoutée à un vin, est dite libre après que la partie restante se soit liée. Les viticulteurs s'efforceront toujours d'obtenir la plus grande proportion de soufre libre pour se lier. On les appelle aussi sulfites et une trop grande quantité est indésirable et donne une odeur piquante (et mal à la tête...)
#
# * le dioxyde de soufre total (***total sulfur dioxide***) en mg/dm<sup>3</sup> : C'est la somme totale du dioxyde de soufre lié et du dioxyde de soufre libre ($SO_2$). Il est principalement ajouté pour tuer les bactéries nocives et préserver la qualité et la fraîcheur. Il existe généralement des limites légales pour les niveaux de soufre dans les vins et un excès peut même tuer de bonnes levures et dégager une odeur indésirable.
#
# * densité (***density***) en g/cm<sup>3</sup>: Elle peut être représentée comme une comparaison du poids d'un volume spécifique de vin à un volume équivalent d'eau. Elle est généralement utilisée comme mesure de la conversion du sucre en alcool.
#
# * le **pH** : Il s'agit d'une échelle numérique permettant de préciser l'acidité ou la basicité du vin. L'acidité fixe est celle qui contribue le plus au pH des vins. Vous le savez peut-être, les solutions dont le pH est inférieur à 7 sont acides, tandis que les solutions dont le pH est supérieur à 7 sont basiques. Avec un pH de 7, l'eau pure est neutre. La plupart des vins ont un pH compris entre 2,9 et 3,9 et sont donc acides.
#
#
# * sulfates (***sulphates***) en g/dm<sup>3</sup>: Ce sont des sels minéraux contenant du soufre. Les sulfates sont au vin ce que le gluten est à la nourriture. Ils font partie intégrante de la vinification dans le monde entier et sont considérés comme essentiels. Ils sont liés au processus de fermentation et affectent l'arôme et la saveur du vin.
#
# * l'alcool (***alcohol***) en % du volume : Le vin est une boisson alcoolisée. L'alcool est formé par la conversion du sucre par la levure pendant le processus de fermentation. Le pourcentage d'alcool peut varier d'un vin à l'autre. Il n'est donc pas surprenant que cet attribut fasse partie de cet ensemble de données.
#
# * qualité (***quality***) : Les experts en vin ont noté la qualité du vin entre 0 (très mauvais) et 10 (excellent). La note finale de qualité est la médiane d'au moins trois évaluations faites par les mêmes experts en vin.
#
# * type_de_vin (***wine_type***) : Comme nous avions à l'origine deux ensembles de données pour le vin rouge et le vin blanc, nous avons introduit cet attribut dans l'ensemble de données fusionné final qui indique le type de vin pour chaque point de données. Un vin peut être soit un vin "rouge", soit un vin "blanc".
#
# * label_qualité (***quality_label***) : Il s'agit d'un attribut dérivé de l'attribut de qualité. Nous classons ou regroupons les notes de qualité du vin en trois catégories qualitatives : faible, moyenne et élevée. Les vins ayant une note de qualité de 3, 4 et 5 sont de faible qualité, les notes de 6 et 7 sont de qualité moyenne et les notes de 8 et 9 sont des vins de haute qualité.
#
#
# ---

# %% [markdown]
# ### **b/ Analyse exploratoire des données et visualisations**

# %% [markdown]
# **Statistiques descriptives sur chaque variable qualitative**
#
# Effectifs, moyenne, écart-type, minimum, quartiles, maximum, pour quelques-unes des variables :

# %%
subset_attributes = ['residual sugar', 'alcohol','pH', 'quality']
rs = round(red_wine[subset_attributes].describe(),2)
rs
# Out:
#        residual sugar  alcohol       pH  quality
# count         1599.00  1599.00  1599.00  1599.00
# mean             2.54    10.42     3.31     5.64
# std              1.41     1.07     0.15     0.81
# min              0.90     8.40     2.74     3.00
# 25%              1.90     9.50     3.21     5.00
# 50%              2.20    10.20     3.31     6.00
# 75%              2.60    11.10     3.40     6.00
# max             15.50    14.90     4.01     8.00

# %%
rs = round(red_wine[subset_attributes].describe(),2)
ws = round(white_wine[subset_attributes].describe(),2)
pd.concat([rs, ws], axis=1, keys=['Red Wine Statistics', 'White Wine Statistics'])
# Out:
#       Red Wine Statistics                            White Wine Statistics  \
#            residual sugar  alcohol       pH  quality        residual sugar
# count             1599.00  1599.00  1599.00  1599.00               4898.00
# mean                 2.54    10.42     3.31     5.64                  6.39
# std                  1.41     1.07     0.15     0.81                  5.07
# min                  0.90     8.40     2.74     3.00                  0.60
# 25%                  1.90     9.50     3.21     5.00                  1.70
# 50%                  2.20    10.20     3.31     6.00                  5.20
# 75%                  2.60    11.10     3.40     6.00                  9.90
# max                 15.50    14.90     4.01     8.00                 65.80
#
#
#        alcohol       pH  quality
# count  4898.00  4898.00  4898.00
# mean     10.51     3.19     5.88
# std       1.23     0.15     0.89
# min       8.00     2.72     3.00
# 25%       9.50     3.09     5.00
# ...

# %% [markdown]
# --> Construire à la main une "boîte à moustaches" (***boxplot***) pour l'une de ces variables, dans les deux catégories de vin, pour comparaisons.
#
# --> Ceci fait, voici comment faire en Python, avec les fonctionnalités propres à Pandas, ou à défaut, de matplotlib

# %%
plt.subplot(1,2,1)
pd.DataFrame.boxplot(white_wine,column = subset_attributes, rot = 30)

plt.subplot(1,2,2)
pd.DataFrame.boxplot(red_wine,column = subset_attributes, rot = 30)
plt.show()

# %%
pd.DataFrame.boxplot(wines,column = subset_attributes, rot = 30)
plt.show()

# %% [markdown]
# Remarque : il est possible d'enregistrer une telle image dans un fichier...

# %%
plt.savefig("my_chart_name.png")

# %% [markdown]
# **Visualisations univariées**
#
# --> Pour l'une des dimensions qualitatives, et pour quelques individus seulement, dresser à la main l'histogramme des effectifs.
#
# --> Ceci fait, voici comment procéder avec la méthode *hist*, présente pour les DataFrames de Pandas, pour visualiser toutes nos dimensions séparément :

# %%
wines.hist(bins=15, color='green', edgecolor='black', linewidth=1.0,
              xlabelsize=8, ylabelsize=8, grid=False)
plt.tight_layout(rect=(0, 0, 1.2, 1.2))

# %% [markdown]
# Voici comment ajouter à un tel graphique titre et légendes, ici, sur la variable "sulphates", quantitative continue :

# %%
fig = plt.figure(figsize = (6,4))
title = fig.suptitle("Sulphates Content in Wine", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel("Sulphates")
ax.set_ylabel("Frequency")
ax.text(1.2, 800, r'$\mu$='+str(round(wines['sulphates'].mean(),2)),
         fontsize=12)
freq, bins, patches = ax.hist(wines['sulphates'], color='steelblue', bins=15,
                                    edgecolor='black', linewidth=1)

# %% [markdown]
# ... et là, sur la variable "quality", quantitative discrète, où le diagramme en barres est plus adapté :

# %%
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("Wine Quality Frequency", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax = fig.add_subplot(1,1, 1)
ax.set_xlabel("Quality")
ax.set_ylabel("Frequency")
w_q = wines['quality'].value_counts()
w_q = (list(w_q.index), list(w_q.values))
ax.tick_params(axis='both', which='major', labelsize=8.5)
bar = ax.bar(w_q[0], w_q[1], color='green',
        edgecolor='black', linewidth=1)

# %% [markdown]
# **Visualisation d'éventuelles corrélations entre deux variables**
#
# Viennent ensuite les comparaisons de variables par couples, par les *scatters plots* (nuages de points) de matplotlib.pyplot

# %%
plt.scatter(wines['sulphates'], wines['alcohol'],
            alpha=0.4, edgecolors='w')

plt.xlabel('Sulphates')
plt.ylabel('Alcohol')
plt.title('Wine Sulphates - Alcohol Content',y=1.05)

plt.show()

# %%
plt.scatter(wines['residual sugar'], wines['density'],
            alpha=0.4, edgecolors='w')

plt.xlabel('residual sugar')
plt.ylabel('density')
plt.title('residual sugar - density',y=1.05)

plt.show()

# %% [markdown]
# Le relatif alignement du nuage de points montre qu'ici, ces deux variables sont très corrélées !
#
#
#
# ---
#
# **Comparaisons entre les deux variables catégorielles entre les deux types de vins**

# %%
fig = plt.figure(figsize = (10, 4))
title = fig.suptitle("Wine Type - Quality", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,2, 1)
ax1.set_title("Red Wine")
ax1.set_xlabel("Quality")
ax1.set_ylabel("Frequency")
rw_q = red_wine['quality'].value_counts()
rw_q = (list(rw_q.index), list(rw_q.values))
ax1.set_ylim([0, 2500])
ax1.tick_params(axis='both', which='major', labelsize=8.5)
bar1 = ax1.bar(rw_q[0], rw_q[1], color='red',
        edgecolor='black', linewidth=1)


ax2 = fig.add_subplot(1,2, 2)
ax2.set_title("White Wine")
ax2.set_xlabel("Quality")
ax2.set_ylabel("Frequency")
ww_q = white_wine['quality'].value_counts()
ww_q = (list(ww_q.index), list(ww_q.values))
ax2.set_ylim([0, 2500])
ax2.tick_params(axis='both', which='major', labelsize=8.5)
bar2 = ax2.bar(ww_q[0], ww_q[1], color='white',
        edgecolor='black', linewidth=1)

# %% [markdown]
# **Comparaison entre attributs mixtes : une variable numérique, une variable catégorielle :**

# %%
fig = plt.figure(figsize = (10,4))
title = fig.suptitle("Sulphates Content in Wine", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,2, 1)
ax1.set_title("Red Wine")
ax1.set_xlabel("Sulphates")
ax1.set_ylabel("Frequency")
ax1.set_ylim([0, 1200])
ax1.text(1.2, 800, r'$\mu$='+str(round(red_wine['sulphates'].mean(),2)),
         fontsize=12)
r_freq, r_bins, r_patches = ax1.hist(red_wine['sulphates'], color='red', bins=15,
                                     edgecolor='black', linewidth=1)

ax2 = fig.add_subplot(1,2, 2)
ax2.set_title("White Wine")
ax2.set_xlabel("Sulphates")
ax2.set_ylabel("Frequency")
ax2.set_ylim([0, 1200])
ax2.text(0.8, 800, r'$\mu$='+str(round(white_wine['sulphates'].mean(),2)),
         fontsize=12)
w_freq, w_bins, w_patches = ax2.hist(white_wine['sulphates'], color='white', bins=15,
                                     edgecolor='black', linewidth=1)

# %% [markdown]
# ---
#
# **Visualisation simultanée de trois variables quantitatives :**
#
# (nécessite l'import d'un autre module pour gérer la 3D...)

# %%
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection = '3d')

xs = wines['residual sugar']
ys = wines['fixed acidity']
zs = wines['alcohol']
ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w')

ax.set_xlabel('Residual Sugar')
ax.set_ylabel('Fixed Acidity')
ax.set_zlabel('Alcohol')

plt.show()

# %% [markdown]
# **Bonus n°1 : un module graphique très performant : Seaborn**
#
# * **Boxplots**

# %%
import seaborn as sns

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Alcohol Content', fontsize=14)

sns.boxplot(x="quality", y="alcohol", hue="wine_type",
               data=wines, palette={"red": "#FF9999", "white": "white"}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Alcohol %",size = 12,alpha=0.8)

sns.boxplot(x="quality_label", y="alcohol", hue="wine_type",
               data=wines, palette={"red": "#FF9999", "white": "white"}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Alcohol %",size = 12,alpha=0.8)
l = plt.legend(loc='best', title='Wine Type')

# %% [markdown]
# * **densité**

# %%
fig = plt.figure(figsize = (6, 4))
title = fig.suptitle("Sulphates Content in Wine", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,1, 1)
ax1.set_xlabel("Sulphates")
ax1.set_ylabel("Density")
sns.kdeplot(wines['sulphates'], ax=ax1, shade=True, color='steelblue')
# Out:
# <ipython-input-46-be13c5ad0f5b>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(wines['sulphates'], ax=ax1, shade=True, color='steelblue')
# <Axes: xlabel='Sulphates', ylabel='Density'>

# %% [markdown]
# * **PairPlot**

# %%
cols = ['density', 'residual sugar', 'total sulfur dioxide', 'fixed acidity']
pp = sns.pairplot(wines[cols], size=1.8, aspect=1.8,
                  plot_kws=dict(edgecolor="k", linewidth=0.5),
                  diag_kind="kde", diag_kws=dict(shade=True))

fig = pp.fig
fig.subplots_adjust(top=0.93, wspace=0.3)
t = fig.suptitle('Wine Attributes Pairwise Plots', fontsize=14)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1507: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=vector, **plot_kwargs)
# ...

# %% [markdown]
# * **HeatMap** (matrice des corrélations)

# %%
f, ax = plt.subplots(figsize=(10, 6))
corr = wines.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
            linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Wine Attributes Correlation Heatmap', fontsize=14)
# Out:
# <ipython-input-48-8be213c5d222>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = wines.corr()

# %% [markdown]
# **Bonus n°2 : le module *pandas-profiling*, qui permet de faire en 1 ligne de code tout ce que nous avons écrit ci-dessus...**
#
# source : https://medium.com/swlh/profiling-in-pandas-351bb6f5804b

# %%
# !pip install pandas_profiling
import pandas_profiling as pp

pp.ProfileReport(wines)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.5/357.5 kB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 12.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 56.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=c1304cd2b4cf64f666b16e9de0ec6600bffa40ed06ae24eb23fed7163041d91a
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
# ...

# %% [markdown]
# ...Juste scandaleux...
#
#
#
# ---
#
#
#
# ---
# ## **6. À vous de jouer**
#
# À vous de mener une Analyse Exploratoire de Données en utilisant ***Pandas*** et ***matplotlib***, prétraîtement sur un jeu de données concernant la détection de patients diabétiques, disponible au format **.csv** ici :
#
# http://www.calvin.edu/~stob/courses/m243/S10/pima.csv
#
# ... ou là : https://frama.link/OT_pima
#
# https://raw.githubusercontent.com/othoni-hub/NSI/main/pima-indians-diabetes.csv
#
# **L'objet d'étude :**
#
# Les Pima sont un groupe d'Amérindiens vivant en Arizona. Une prédisposition génétique a permis à ce groupe de survivre normalement à un régime pauvre en glucides pendant des années. Ces dernières années, en raison du passage soudain des cultures agricoles traditionnelles aux aliments transformés, ainsi que du déclin de l'activité physique, ils ont développé la plus forte prévalence de diabète de type 2 et c'est pour cette raison qu'ils ont fait l'objet de nombreuses études.
#
# **Les données :**
#
# Elles concernent des jeunes femmes de plus de 21 ans.
#
# **Les variables :**
#
# Les ensembles de données se composent de plusieurs variables prédictives médicales et d'une variable cible, *'Outcome'*.
#
# Les colonnes sont les suivantes :-
# 1. **Grossesses** (*Pregnancies*) : Nombre de fois où la femme a été enceinte
#
# 2. **Glucose** : Concentration de glucose plasmatique dans un test de tolérance au glucose par voie orale
#
# 3. **Pression sanguine** (*BloodPressure*) : Pression sanguine diastolique (mm Hg)
#
# 4. **Épaisseur de la peau** (*SkinThickness*) : Épaisseur du pli cutané du triceps (mm)
#
# 5. **Insuline** (*Insulin*) : insuline sérique (mu U/ml)
#
# 6. **IMC** (*BMI*) : - Indice de masse corporelle (poids en kg/(taille en m)²)
#
# 7. **DiabetesPedigreeFunction** : Fonction du pedigree du diabète
#
# 8. **Age** : Âge en années
#
# 9. **Résultat** (*Outcome*) :  Variable de classe (0 ou 1) 268 sur 768 sont 1, c'est-à-dire positives au diabète de type II, les autres sont 0.
#
#
# **Import des bibliothèques et téléchargement des données**
# Les données seront désérialisée dans un DataFrame df.
#
# **Exploration générale des données et prétraitement :**
# * Quelle est la taille du jeu de données ?
# * De quels types sont-elles ?
# * Quelles sont les caractéristiques statistiques de ces séries ?
# * Y a-t-il des valeurs manquantes ? ...commande : df.isnull().values.any().
# * Les valeurs égales à 0 n'ont pas de sens dans les colonnes 2 à 8, les remplacer par la valeur *'Nan'* ! ...commande : d=df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]=df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']].replace(0,np.nan)
#
# * Compter ces valeurs dans lesdites colonnes. ...commande : d.isnull().sum()[['Glucose','BloodPressure','SkinThickness','Insulin','BMI'
#
# * Remplacer les *'NaN'* par la médiane de la série. ...commande pour la colonne 'glucose' : pima_data['Glucose'].fillna(pima_data['Glucose'].median(),inplace=True)
#
# **Visualisations des variables une à une**
#
# * Effectuer un graphique adapté pour comparer diabétiques et non diabétiques sur l'ensemble de la population étudiée.
#
# * Effectuer un diagramme adapté pour chaque variable.
#
# * Tracer les boîtes à moustaches (*BoxPlots*) pour chaque variable. QU'est-ce que cela permet de repérer ? Pourquoi avons-nous remplacé les *'NaN'* par la médiane de leur série ?
#
# **Visualisation des variables deux à deux**
#
# * Visualiser les nuages de points des variables prises deux à deux.
#
# * Calculer la matrice des corrélations des variables prise deux à deux et faire afficher la ***heatmap***
#
#
# **Facultatif : analyse bivariée du résultat du test en fonction de l'âge**
#
# * Tracer un graphique permettant de visualiser les pourcentages de diabétiques pour chaque tranche d'âge d'amplitude 5 ans (avec une classe '>55')
#
# **Conclusion ?**

# %% [markdown]
# **Corrigé ici :**
# https://www.kaggle.com/saurav9786/eda-makes-sense
